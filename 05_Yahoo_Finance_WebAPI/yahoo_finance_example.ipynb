# %% [markdown]
# # Stock market analysis using data from the Yahoo-Finance Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import ta
import fnmatch
import pandas as pd
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt

# Define settings for graphics
# plt.style.use('dark_background')

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(os.getcwd())
# Out:
# /home/pfrei/Dokumente/GitHub/data_ingestion/05_Yahoo_Finance_WebAPI

# %% [markdown]
# ## Get data
# List of stock market symbols: https://finance.yahoo.com/lookup

# %%
# Retrieve the Microsoft stock data from Yahoo finance
today = datetime.now().strftime("%Y-%m-%d")
print('Today is:', today)

data = yf.download('MSFT', start = "2022-01-01", end = today, progress=False)
data.tail()
# Out:
# Today is: 2025-11-07
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-10-29  541.549988  546.270020  536.729980  544.940002  36023000
# 2025-10-30  525.760010  534.969971  522.119995  530.479980  41023100
# 2025-10-31  517.809998  529.320007  515.099976  528.880005  34006400
# 2025-11-03  517.030029  524.960022  514.590027  519.809998  22374700
# 2025-11-04  514.330017  515.549988  507.839996  511.760010  20958700

# %% [markdown]
# ## Calculate techniqual indicators

# %%
# Function to compute Bollinger Bands 
def BBANDS(data, n):
    MA = data.Close.rolling(window=n).mean()
    SD = data.Close.rolling(window=n).std()
    data['MiddleBand'] = MA
    data['UpperBand'] = MA + (2 * SD) 
    data['LowerBand'] = MA - (2 * SD)
    return data
 
# Compute the Bollinger Bands for Google using the 50-day Moving average
BBANDS = BBANDS(data, 50)
BBANDS
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2022-01-03  324.504608  327.655138  319.686719  325.086250  28865100
# 2022-01-04  318.940247  324.940796  316.138684  324.582096  32674300
# 2022-01-05  306.696838  316.090267  306.309087  315.886673  40054300
# 2022-01-06  304.273346  308.945831  301.956480  303.565678  39646100
# 2022-01-07  304.428497  306.813198  300.599379  304.535116  32720000
# ...                ...         ...         ...         ...       ...
# 2025-10-29  541.549988  546.270020  536.729980  544.940002  36023000
# 2025-10-30  525.760010  534.969971  522.119995  530.479980  41023100
# 2025-10-31  517.809998  529.320007  515.099976  528.880005  34006400
# 2025-11-03  517.030029  524.960022  514.590027  519.809998  22374700
# 2025-11-04  514.330017  515.549988  507.839996  511.760010  20958700
#
# Price       MiddleBand   UpperBand   LowerBand
# Ticker
# Date
# 2022-01-03         NaN         NaN         NaN
# 2022-01-04         NaN         NaN         NaN
# 2022-01-05         NaN         NaN         NaN
# 2022-01-06         NaN         NaN         NaN
# 2022-01-07         NaN         NaN         NaN
# ...                ...         ...         ...
# 2025-10-29  513.136599  532.886285  493.386912
# 2025-10-30  513.553998  533.473730  493.634267
# 2025-10-31  513.825399  533.596388  494.054410
# 2025-11-03  514.021399  533.719688  494.323110
# 2025-11-04  514.222799  533.718605  494.726993
#
# [964 rows x 8 columns]

# %% [markdown]
# ## Plot data and techniqual indicators

# %%
# Create the plot
plt.figure(figsize=(10, 5))

# Set the title and axis labels
plt.title('Bollinger Bands')
plt.xlabel('Date')
plt.ylabel('Price (USD)')

plt.plot(BBANDS.Close, lw=1.0, label='Close Price')
plt.plot(data['UpperBand'], 'g--', lw=0.5, label='Upper band')
plt.plot(data['MiddleBand'], 'r--', lw=0.5, label='Middle band')
plt.plot(data['LowerBand'], 'g--', lw=0.5, label='Lower band')

# Add a legend to the axis
plt.legend()

plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-87-generic
# Datetime: 2025-11-07 15:31:57
# Python Version: 3.12.12
# -----------------------------------
